# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
df = pd.read_csv('credit_card_fraud_10k.csv')

# %%
x=df['merchant_category']
y=df['cardholder_age']

plt.plot(x,y)

plt.title("merchant_category vs cardholder_age")
plt.grid(True)
plt.legend()
plt.show()
# Out:
# C:\Users\anime\AppData\Local\Temp\ipykernel_20896\34389493.py:8: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
